# %% [markdown]
# Exploring Datasets with pandas and Matplotlib
# Toolkits: The course heavily relies on pandas and Numpy for data wrangling, analysis, and visualization. The primary plotting library we will explore is Matplotlib.
#
# Dataset: Immigration to Canada from 1980 to 2013 - International migration flows to and from selected countries in Africa .- The 2015 revision from United Nation's website
#
# The dataset contains annual data on the flows of international migrants as recorded by the countries of destination. The data presents both inflows and outflows according to the place of birth, citizenship or place of previous / next residence both for foreigners and nationals. In this lab, we will focus on the Canadian Immigration data.
#
# Downloading and Prepping Data
# Import Primary Modules:
#
# import numpy as np  # useful for many scientific computing in Python
# import pandas as pd # primary data structure library
# from PIL import Image # converting images into arrays
# Let's download and import our primary Canadian Immigration dataset using pandas read_excel() method. Normally, before we can do that, we would need to download a module which pandas requires to read in excel files. This module is xlrd. For your convenience, we have pre-installed this module, so you would not have to worry about that. Otherwise, you would need to run the following line of code to install the xlrd module:
#
# !conda install -c anaconda xlrd --yes
# Download the dataset and read it into a pandas dataframe:

# %%
import numpy as np  # useful for many scientific computing in Python
import pandas as pd # primary data structure library
from PIL import Image # converting images into arrays

# %%
# !conda install -c anaconda xlrd --yes
df_can = pd.read_excel('https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DV0101EN/labs/Data_Files/Canada.xlsx',

                       sheet_name='Canada by Citizenship',
                       skiprows=range(20),
                       skipfooter=2
                    
                
                      )

print('Data downloaded and read into a dataframe')
# Out:
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
# Data downloaded and read into a dataframe

# %%
df_can.head(100)
# Out:
#           Type    Coverage                            OdName  AREA  \
# 0   Immigrants  Foreigners                       Afghanistan   935
# 1   Immigrants  Foreigners                           Albania   908
# 2   Immigrants  Foreigners                           Algeria   903
# 3   Immigrants  Foreigners                    American Samoa   909
# 4   Immigrants  Foreigners                           Andorra   908
# 5   Immigrants  Foreigners                            Angola   903
# 6   Immigrants  Foreigners               Antigua and Barbuda   904
# 7   Immigrants  Foreigners                         Argentina   904
# 8   Immigrants  Foreigners                           Armenia   935
# 9   Immigrants  Foreigners                         Australia   909
# 10  Immigrants  Foreigners                           Austria   908
# 11  Immigrants  Foreigners                        Azerbaijan   935
# 12  Immigrants  Foreigners                           Bahamas   904
# 13  Immigrants  Foreigners                           Bahrain   935
# 14  Immigrants  Foreigners                        Bangladesh   935
# 15  Immigrants  Foreigners                          Barbados   904
# 16  Immigrants  Foreigners                           Belarus   908
# 17  Immigrants  Foreigners                           Belgium   908
# 18  Immigrants  Foreigners                            Belize   904
# 19  Immigrants  Foreigners                             Benin   903
# 20  Immigrants  Foreigners                            Bhutan   935
# 21  Immigrants  Foreigners  Bolivia (Plurinational State of)   904
# 22  Immigrants  Foreigners            Bosnia and Herzegovina   908
# 23  Immigrants  Foreigners                          Botswana   903
# 24  Immigrants  Foreigners                            Brazil   904
# 25  Immigrants  Foreigners                 Brunei Darussalam   935
# 26  Immigrants  Foreigners                          Bulgaria   908
# 27  Immigrants  Foreigners                      Burkina Faso   903
# 28  Immigrants  Foreigners                           Burundi   903
# 29  Immigrants  Foreigners                        Cabo Verde   903
# ..         ...         ...                               ...   ...
# 70  Immigrants  Foreigners                           Grenada   904
# 71  Immigrants  Foreigners                         Guatemala   904
# 72  Immigrants  Foreigners                            Guinea   903
# 73  Immigrants  Foreigners                     Guinea-Bissau   903
# 74  Immigrants  Foreigners                            Guyana   904
# 75  Immigrants  Foreigners                             Haiti   904
# 76  Immigrants  Foreigners                          Honduras   904
# 77  Immigrants  Foreigners                           Hungary   908
# 78  Immigrants  Foreigners                           Iceland   908
# 79  Immigrants  Foreigners                             India   935
# 80  Immigrants  Foreigners                         Indonesia   935
# 81  Immigrants  Foreigners        Iran (Islamic Republic of)   935
# 82  Immigrants  Foreigners                              Iraq   935
# 83  Immigrants  Foreigners                           Ireland   908
# 84  Immigrants  Foreigners                            Israel   935
# 85  Immigrants  Foreigners                             Italy   908
# 86  Immigrants  Foreigners                           Jamaica   904
# 87  Immigrants  Foreigners                             Japan   935
# 88  Immigrants  Foreigners                            Jordan   935
# 89  Immigrants  Foreigners                        Kazakhstan   935
# 90  Immigrants  Foreigners                             Kenya   903
# 91  Immigrants  Foreigners                          Kiribati   909
# 92  Immigrants  Foreigners                            Kuwait   935
# 93  Immigrants  Foreigners                        Kyrgyzstan   935
# 94  Immigrants  Foreigners  Lao People's Democratic Republic   935
# 95  Immigrants  Foreigners                            Latvia   908
# 96  Immigrants  Foreigners                           Lebanon   935
# 97  Immigrants  Foreigners                           Lesotho   903
# 98  Immigrants  Foreigners                           Liberia   903
# 99  Immigrants  Foreigners                             Libya   903
#
#                            AreaName   REG                    RegName  DEV  \
# 0                              Asia  5501              Southern Asia  902
# 1                            Europe   925            Southern Europe  901
# 2                            Africa   912            Northern Africa  902
# 3                           Oceania   957                  Polynesia  902
# 4                            Europe   925            Southern Europe  901
# 5                            Africa   911              Middle Africa  902
# 6   Latin America and the Caribbean   915                  Caribbean  902
# 7   Latin America and the Caribbean   931              South America  902
# 8                              Asia   922               Western Asia  902
# 9                           Oceania   927  Australia and New Zealand  901
# 10                           Europe   926             Western Europe  901
# 11                             Asia   922               Western Asia  902
# 12  Latin America and the Caribbean   915                  Caribbean  902
# 13                             Asia   922               Western Asia  902
# 14                             Asia  5501              Southern Asia  902
# 15  Latin America and the Caribbean   915                  Caribbean  902
# 16                           Europe   923             Eastern Europe  901
# 17                           Europe   926             Western Europe  901
# 18  Latin America and the Caribbean   916            Central America  902
# 19                           Africa   914             Western Africa  902
# 20                             Asia  5501              Southern Asia  902
# 21  Latin America and the Caribbean   931              South America  902
# 22                           Europe   925            Southern Europe  901
# 23                           Africa   913            Southern Africa  902
# 24  Latin America and the Caribbean   931              South America  902
# 25                             Asia   920         South-Eastern Asia  902
# 26                           Europe   923             Eastern Europe  901
# 27                           Africa   914             Western Africa  902
# 28                           Africa   910             Eastern Africa  902
# 29                           Africa   914             Western Africa  902
# ..                              ...   ...                        ...  ...
# 70  Latin America and the Caribbean   915                  Caribbean  902
# 71  Latin America and the Caribbean   916            Central America  902
# 72                           Africa   914             Western Africa  902
# 73                           Africa   914             Western Africa  902
# 74  Latin America and the Caribbean   931              South America  902
# 75  Latin America and the Caribbean   915                  Caribbean  902
# 76  Latin America and the Caribbean   916            Central America  902
# 77                           Europe   923             Eastern Europe  901
# 78                           Europe   924            Northern Europe  901
# 79                             Asia  5501              Southern Asia  902
# 80                             Asia   920         South-Eastern Asia  902
# 81                             Asia  5501              Southern Asia  902
# 82                             Asia   922               Western Asia  902
# 83                           Europe   924            Northern Europe  901
# 84                             Asia   922               Western Asia  902
# 85                           Europe   925            Southern Europe  901
# 86  Latin America and the Caribbean   915                  Caribbean  902
# 87                             Asia   906               Eastern Asia  901
# 88                             Asia   922               Western Asia  902
# 89                             Asia  5500               Central Asia  902
# 90                           Africa   910             Eastern Africa  902
# 91                          Oceania   954                 Micronesia  902
# 92                             Asia   922               Western Asia  902
# 93                             Asia  5500               Central Asia  902
# 94                             Asia   920         South-Eastern Asia  902
# 95                           Europe   924            Northern Europe  901
# 96                             Asia   922               Western Asia  902
# 97                           Africa   913            Southern Africa  902
# 98                           Africa   914             Western Africa  902
# 99                           Africa   912            Northern Africa  902
#
#                DevName  1980  ...     2004   2005   2006   2007   2008   2009  \
# 0   Developing regions    16  ...     2978   3436   3009   2652   2111   1746
# 1    Developed regions     1  ...     1450   1223    856    702    560    716
# 2   Developing regions    80  ...     3616   3626   4807   3623   4005   5393
# 3   Developing regions     0  ...        0      0      1      0      0      0
# 4    Developed regions     0  ...        0      0      1      1      0      0
# 5   Developing regions     1  ...      268    295    184    106     76     62
# 6   Developing regions     0  ...       14     24     32     15     32     38
# 7   Developing regions   368  ...     1591   1153    847    620    540    467
# 8   Developing regions     0  ...      147    224    218    198    205    267
# 9    Developed regions   702  ...      930    909    875   1033   1018   1018
# 10   Developed regions   234  ...      118    122    102     98     91    109
# 11  Developing regions     0  ...      230    359    236    203    125    165
# 12  Developing regions    26  ...       13     14     18     23     30     27
# 13  Developing regions     0  ...       12     12     12     22      9     35
# 14  Developing regions    83  ...     2660   4171   4014   2897   2939   2104
# 15  Developing regions   372  ...       90    111     97    130    134    125
# 16   Developed regions     0  ...      543    558    439    568    524    454
# 17   Developed regions   511  ...      411    400    302    363    335    358
# 18  Developing regions    16  ...       25     37     24     28     48     38
# 19  Developing regions     2  ...      112     95    116    183    205    238
# 20  Developing regions     0  ...        1      5     10      7     36    865
# 21  Developing regions    44  ...       85    134    139    107    143    214
# 22   Developed regions     0  ...      188    211    217    209    182    156
# 23  Developing regions    10  ...        9      7     11      8     28     15
# 24  Developing regions   211  ...      917    969   1181   1746   2138   2509
# 25  Developing regions    79  ...        3      4      5     11     10      5
# 26   Developed regions    24  ...     2022   1738   1419   1172    994    784
# 27  Developing regions     2  ...       97     91    147    136    139    162
# 28  Developing regions     0  ...      559    626    468    614    448    566
# 29  Developing regions     1  ...        3      5      7      2      5      1
# ..                 ...   ...  ...      ...    ...    ...    ...    ...    ...
# 70  Developing regions   154  ...      296    283    363    360    284    325
# 71  Developing regions   114  ...      217    190    230    258    263    264
# 72  Developing regions     0  ...      281    256    342    415    327    347
# 73  Developing regions     0  ...        4      7     12      7      2      0
# 74  Developing regions  2334  ...     1341   1215   1286   1277   1137   1180
# 75  Developing regions  1666  ...     1652   1682   1619   1598   2491   2080
# 76  Developing regions    26  ...      133    166    164    165    187    169
# 77   Developed regions   205  ...      671    516    520    425    383    312
# 78   Developed regions    17  ...       23     10      2     15     13     15
# 79  Developing regions  8880  ...    28235  36210  33848  28742  28261  29456
# 80  Developing regions   186  ...      552    632    613    657    661    504
# 81  Developing regions  1172  ...     6348   5837   7480   6974   6475   6580
# 82  Developing regions   262  ...     1796   2226   1788   2406   3543   5450
# 83   Developed regions   781  ...      244    224    283    300    412    395
# 84  Developing regions  1403  ...     2788   2446   2625   2401   2562   2316
# 85   Developed regions  1820  ...      334    344    325    320    370    429
# 86  Developing regions  3198  ...     2237   1945   1722   2141   2334   2456
# 87   Developed regions   701  ...      973   1067   1212   1250   1284   1194
# 88  Developing regions   177  ...     1733   1940   1827   1421   1581   1235
# 89  Developing regions     0  ...      545    506    408    436    394    431
# 90  Developing regions   291  ...      685    693    622    449    453    489
# 91  Developing regions     0  ...        0      1      0      0      1      1
# 92  Developing regions     1  ...       74     66     35     62     53     68
# 93  Developing regions     0  ...      245    173    161    135    168    173
# 94  Developing regions    11  ...       38     42     74     53     32     39
# 95   Developed regions     0  ...       94     77     69     88     67     85
# 96  Developing regions  1409  ...     3293   3709   3802   3467   3566   3077
# 97  Developing regions     1  ...        2      4      0      4      1      8
# 98  Developing regions     1  ...      409    581    356    153     74     94
# 99  Developing regions     5  ...      196    196    281    198    306    282
#
#      2010   2011   2012   2013
# 0    1758   2203   2635   2004
# 1     561    539    620    603
# 2    4752   4325   3774   4331
# 3       0      0      0      0
# 4       0      0      1      1
# 5      61     39     70     45
# 6      27     37     51     25
# 7     459    278    263    282
# 8     252    236    258    207
# 9     933    851    982   1121
# 10    124     84    102     90
# 11    209    138    161     57
# 12     25     40     60     55
# 13     28     21     39     32
# 14   4721   2694   2640   3789
# 15    121     97    132     97
# 16    438    357    277    247
# 17    363    332    402    379
# 18     39     36     34     53
# 19    290    284    391    397
# 20   1464   1879   1075    487
# 21    180     86     83    107
# 22    168    140    121    119
# 23     42     53     64     76
# 24   2598   1508   1642   1714
# 25     12      6      3      6
# 26    556    365    451    512
# 27    186    144    269    322
# 28    529    604    684    480
# 29      3      3      6      2
# ..    ...    ...    ...    ...
# 70    208    173    142    170
# 71    266    288    358    345
# 72    395    352    407    463
# 73      2      2      4      0
# 74    953    804    676    656
# 75   4744   6503   5868   4152
# 76    386    538    436    350
# 77    354    287    300    425
# 78     30     38     42     72
# 79  34235  27509  30933  33087
# 80    712    390    395    387
# 81   7477   7479   7534  11291
# 82   5941   6196   4041   4918
# 83    547    525    725   1015
# 84   2755   1970   2134   1945
# 85    434    374    440    545
# 86   2321   2059   2182   2479
# 87   1168   1265   1214    982
# 88   1831   1635   1206   1255
# 89    377    381    462    348
# 90    507    585    725    664
# 91      0      0      2      0
# 92     67     58     73     48
# 93    157    159    278    123
# 94     54     22     25     15
# 95     70    103    202    213
# 96   3432   3072   1614   2172
# 97      7      1      0      6
# 98    162    106     58     39
# 99    384    352    299    255
#
# [100 rows x 43 columns]

# %%
# print the dimensions of the dataframe
print(df_can.shape)
# Out:
# (195, 43)

# %%
# clean up the dataset to remove unnecessary columns (eg. REG) 
df_can.drop(['AREA','REG','DEV','Type','Coverage'], axis = 1, inplace = True)

# let's rename the columns so that they make sense
df_can.rename (columns = {'OdName':'Country', 'AreaName':'Continent','RegName':'Region'}, inplace = True)

# for sake of consistency, let's also make all column labels of type string
df_can.columns = list(map(str, df_can.columns))

# set the country name as index - useful for quickly looking up countries using .loc method
df_can.set_index('Country', inplace = True)

# add total column
df_can['Total'] =  df_can.sum (axis = 1)

# years that we will be using in this lesson - useful for plotting later on
years = list(map(str, range(1980, 2014)))
print ('data dimensions:', df_can.shape)
# Out:
# data dimensions: (195, 38)

# %%
# %matplotlib inline

import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches # needed for waffle Charts

mpl.style.use('ggplot') # optional: for ggplot-like style

# check for latest version of Matplotlib
print ('Matplotlib version: ', mpl.__version__) # >= 2.0.0
# Out:
# Matplotlib version:  3.0.2

# %% [markdown]
# # Waffle Charts <a id="6"></a>
#
#
# A `waffle chart` is an interesting visualization that is normally created to display progress toward goals. It is commonly an effective option when you are trying to add interesting visualization features to a visual that consists mainly of cells, such as an Excel dashboard.

# %%
# let's create a new dataframe for these three countries 
df_dsn = df_can.loc[['Zambia', 'Malawi', 'Botswana'], :]

# let's take a look at our dataframe
df_dsn

# let's create a new dataframe for these three countries 
#df_dsn = df_can.loc[['Zambia','Malawi', 'Botswana'], :], 

# let's take a look at our dataframe
#df_dsn
# Out:
#          Continent           Region             DevName  1980  1981  1982  \
# Country
# Zambia      Africa   Eastern Africa  Developing regions    11    17    11
# Malawi      Africa   Eastern Africa  Developing regions     5     4     6
# Botswana    Africa  Southern Africa  Developing regions    10     1     3
#
#           1983  1984  1985  1986  ...    2005  2006  2007  2008  2009  2010  \
# Country                           ...
# Zambia       7    16     9    15  ...      91    77    71    64    60   102
# Malawi       3     2     0     4  ...      23    15    13     5    10    28
# Botswana     3     7     4     2  ...       7    11     8    28    15    42
#
#           2011  2012  2013  Total
# Country
# Zambia      69    46    59   1677
# Malawi      16     9    10    294
# Botswana    53    64    76    396
#
# [3 rows x 38 columns]

# %%
# compute the proportion of each category with respect to the total
total_values = sum(df_dsn['Total'])
category_proportions = [(float(value) / total_values) for value in df_dsn['Total']]

# print out proportions
for i, proportion in enumerate(category_proportions):
    print (df_dsn.index.values[i] + ': ' + str(proportion))
# Out:
# Zambia: 0.7084917617237009
# Malawi: 0.12420785804816223
# Botswana: 0.16730038022813687

# %%
width = 40 # width of chart
height = 10 # height of chart

total_num_tiles = width * height # total number of tiles

print ('Total number of tiles is ', total_num_tiles)
# Out:
# Total number of tiles is  400

# %%
# compute the number of tiles for each catagory
tiles_per_category = [round(proportion * total_num_tiles) for proportion in category_proportions]

# print out number of tiles per category
for i, tiles in enumerate(tiles_per_category):
    print (df_dsn.index.values[i] + ': ' + str(tiles))
# Out:
# Zambia: 283
# Malawi: 50
# Botswana: 67

# %%
# compute the proportion of each category with respect to the total
total_values = sum(df_dsn['Total'])
category_proportions = [(float(value) / total_values) for value in df_dsn['Total']]

# print out proportions
for i, proportion in enumerate(category_proportions):
    print (df_dsn.index.values[i] + ': ' + str(proportion))
# Out:
# Zambia: 0.7084917617237009
# Malawi: 0.12420785804816223
# Botswana: 0.16730038022813687

# %%
width = 40 # width of chart
height = 10 # height of chart

total_num_tiles = width * height # total number of tiles

print ('Total number of tiles is ', total_num_tiles)
# Out:
# Total number of tiles is  400

# %%
# compute the number of tiles for each catagory
tiles_per_category = [round(proportion * total_num_tiles) for proportion in category_proportions]

# print out number of tiles per category
for i, tiles in enumerate(tiles_per_category):
    print (df_dsn.index.values[i] + ': ' + str(tiles))
# Out:
# Zambia: 283
# Malawi: 50
# Botswana: 67

# %%
# initialize the waffle chart as an empty matrix
waffle_chart = np.zeros((height, width))

# define indices to loop through waffle chart
category_index = 0
tile_index = 0

# populate the waffle chart
for col in range(width):
    for row in range(height):
        tile_index += 1

        # if the number of tiles populated for the current category is equal to its corresponding allocated tiles...
        if tile_index > sum(tiles_per_category[0:category_index]):
            # ...proceed to the next category
            category_index += 1       
            
        # set the class value to an integer, which increases with class
        waffle_chart[row, col] = category_index
        
print ('Waffle chart populated!')
# Out:
# Waffle chart populated!

# %%
# instantiate a new figure object
fig = plt.figure()

# use matshow to display the waffle chart
colormap = plt.cm.coolwarm
plt.matshow(waffle_chart, cmap=colormap)
plt.colorbar()

# get the axis
ax = plt.gca()

# set minor ticks
ax.set_xticks(np.arange(-.5, (width), 1), minor=True)
ax.set_yticks(np.arange(-.5, (height), 1), minor=True)
    
# add gridlines based on minor ticks
ax.grid(which='minor', color='w', linestyle='-', linewidth=2)

plt.xticks([])
plt.yticks([])

# compute cumulative sum of individual categories to match color schemes between chart and legend
values_cumsum = np.cumsum(df_dsn['Total'])
total_values = values_cumsum[len(values_cumsum) - 1]

# create legend
legend_handles = []
for i, category in enumerate(df_dsn.index.values):
    label_str = category + ' (' + str(df_dsn['Total'][i]) + ')'
    color_val = colormap(float(values_cumsum[i])/total_values)
    legend_handles.append(mpatches.Patch(color=color_val, label=label_str))

# add legend to chart
plt.legend(handles=legend_handles,
           loc='lower center', 
           ncol=len(df_dsn.index.values),
           bbox_to_anchor=(0., -0.2, 0.95, .1)
          )

# %%
# use the inline backend to generate the plots within the browser
# %matplotlib inline 

import matplotlib as mpl
import matplotlib.pyplot as plt

mpl.style.use('ggplot') # optional: for ggplot-like style

# check for latest version of Matplotlib
print ('Matplotlib version: ', mpl.__version__) # >= 2.0.0
# Out:
# Matplotlib version:  3.0.2

# %%
df_dsn.sort_values(['Total'], ascending=False, axis=0, inplace=True)

# get the top 5 entries
df_top5 = df_dsn.head() #df_can.head()

# transpose the dataframe
df_top5 = df_top5[years].transpose() 

df_top5.head()
# Out:
# Country  Zambia  Botswana  Malawi
# 1980         11        10       5
# 1981         17         1       4
# 1982         11         3       6
# 1983          7         3       3
# 1984         16         7       2

# %%
df_top5.index = df_top5.index.map(int) # let's change the index values of df_top5 to type integer for plotting
df_top5.plot(kind='area', 
             stacked=False,
             figsize=(20, 10), # pass a tuple (x, y) size
             )

plt.title('Immigration Trend of Top 5 Countries')
plt.ylabel('Number of Immigrants')
plt.xlabel('Years')

plt.show()

# %%
# install seaborn
#!conda install -c anaconda seaborn --yes

# import library
import seaborn as sns

print('Seaborn installed and imported!')
# Out:
# Seaborn installed and imported!

# %%
# we can use the sum() method to get the total population per year
df_tot = df_top5.head()
df_tot = pd.DataFrame(df_can[years].sum(axis=0))

# change the years to type float (useful for regression later on)
df_tot.index = map(float, df_tot.index)

# reset the index to put in back in as a column in the df_tot dataframe
df_tot.reset_index(inplace=True)

# rename columns
df_tot.columns = ['year', 'total']

# view the final dataframe
df_tot.head()
# Out:
#      year   total
# 0  1980.0   99137
# 1  1981.0  110563
# 2  1982.0  104271
# 3  1983.0   75550
# 4  1984.0   73417

# %%
import seaborn as sns
plt.figure(figsize=(15, 10))

sns.set(font_scale=1.5)
ax = sns.regplot(x='year', y='total', data=df_tot, color='green')
# Out:
# C:\Users\emma\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
